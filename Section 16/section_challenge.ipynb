# %%
from PIL import Image

# %%
word_matrix = Image.open('word_matrix.png')

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FE57EC471C0>

# %%
mask = Image.open('mask.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x7FE580372550>

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
mask.resize((1015, 599))
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x599 at 0x7FE5803728E0>

# %%
mask.putalpha(100)

# %%
mask.save('transp.png', 'PNG')

# %%
transparent = Image.open('transp.png')
transparent.resize((1015, 559)).save('transp.png', 'PNG')
transparent = Image.open('transp.png')

# %%
word_matrix.paste(im=transparent, box=(0,0), mask=transparent)

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FE57EC471C0>
